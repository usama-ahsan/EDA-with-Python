# %%
import numpy
import pandas
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy
#       2 import pandas
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
df=pd.read_csv('titanic.csv')    #read the csv

# %%
df.head()

# %%
df.isna().any().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.isna().any().any()
#
# NameError: name 'df' is not defined

# %%
df.describe() #show some eda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.describe() #show some eda
#
# NameError: name 'df' is not defined

# %%
df.info() #show memory usage
